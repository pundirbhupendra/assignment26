# %% [markdown]
# # Python OOP Assignment

# %% [markdown]
# ## Q1. Create a Vehicle class with instance variables.

# %%
class Vehicle:
    def __init__(self, name_of_vehicle, max_speed, average_of_vehicle):
        self.name_of_vehicle = name_of_vehicle
        self.max_speed = max_speed
        self.average_of_vehicle = average_of_vehicle

vehicle = Vehicle("Car", 180, 20)

print(vehicle.name_of_vehicle)
print(vehicle.max_speed)
print(vehicle.average_of_vehicle)

# %% [markdown]
# ## Q2. Create a child class Car inheriting Vehicle class.

# %%
class Vehicle:
    def __init__(self, name_of_vehicle, max_speed, average_of_vehicle):
        self.name_of_vehicle = name_of_vehicle
        self.max_speed = max_speed
        self.average_of_vehicle = average_of_vehicle

class Car(Vehicle):
    def seating_capacity(self, capacity):
        return f"Vehicle Name: {self.name_of_vehicle}, Seating Capacity: {capacity}"

car = Car("Toyota", 180, 18)

print(car.seating_capacity(5))

# %% [markdown]
# ## Q3. Multiple Inheritance Example

# %%
class Father:
    def father_property(self):
        print("Father's Property")

class Mother:
    def mother_property(self):
        print("Mother's Property")

class Child(Father, Mother):
    pass

child = Child()

child.father_property()
child.mother_property()

# %% [markdown]
# ## Q4. Getter and Setter Example

# %%
class Student:
    def __init__(self):
        self.__marks = 0

    def set_marks(self, marks):
        self.__marks = marks

    def get_marks(self):
        return self.__marks

student = Student()
student.set_marks(95)

print(student.get_marks())

# %% [markdown]
# ## Q5. Method Overriding Example

# %%
class Animal:
    def sound(self):
        print("Animal makes a sound")

class Dog(Animal):
    def sound(self):
        print("Dog barks")

dog = Dog()
dog.sound()
