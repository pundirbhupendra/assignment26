# %% [markdown]
# # Flask Assignment

# %% [markdown]
# ## Q1. What is Flask Framework? What are the advantages of Flask Framework?

# %%
# Flask is a lightweight Python web framework used to build web applications.

# Advantages of Flask:
# 1. Lightweight and simple
# 2. Easy to learn
# 3. Flexible framework
# 4. Built-in development server
# 5. Supports RESTful request handling
# 6. Easy integration with databases

# %% [markdown]
# ## Q2. Create a simple Flask application to display 'Hello World!!'.

# %%
from flask import Flask

app = Flask(__name__)

@app.route('/')
def hello_world():
    return "Hello World!!"

if __name__ == '__main__':
    app.run()

# %% [markdown]
# ## Q3. What is App routing in Flask? Why do we use app routes?

# %%
# App routing in Flask maps URLs to Python functions.

# We use app routes to:
# 1. Define web pages
# 2. Handle different URLs
# 3. Create APIs and web applications

# %% [markdown]
# ## Q4. Create '/welcome' and '/' routes.

# %%
from flask import Flask

app = Flask(__name__)

@app.route('/welcome')
def welcome():
    return "Welcome to ABC Corporation"

@app.route('/')
def company_details():
    return '''
    Company Name: ABC Corporation<br>
    Location: India<br>
    Contact Detail: 999-999-9999
    '''

if __name__ == '__main__':
    app.run()

# %% [markdown]
# ## Q5. Explain url_for() function.

# %%
from flask import Flask, url_for

app = Flask(__name__)

@app.route('/home')
def home():
    return "Home Page"

@app.route('/about')
def about():
    return url_for('home')

if __name__ == '__main__':
    app.run()

# url_for() is used for URL building dynamically.

# %% [markdown]
# ## Screenshot of Hello World Output

# %% [markdown]
# ![Hello World Screenshot](flask_hello_world.png)

# %% [markdown]
# ## Screenshot of Routes Output

# %% [markdown]
# ![Routes Screenshot](flask_routes.png)
